# %% [markdown]
# # How to find Censoring Rectangles
#
# From the [r/Place dataset post](https://www.reddit.com/r/place/comments/txvk2d/rplace_datasets_april_fools_2022/):
#
# > _Inside the dataset there are instances of moderators using a rectangle drawing tool to handle inappropriate content. These rows differ in the coordinate tuple which contain four values instead of two–“x1,y1,x2,y2” corresponding to the upper left x1, y1 coordinate and the lower right x2, y2 coordinate of the moderation rect. These events apply the specified color to all tiles within those two points, inclusive._
#
# It may be useful to find all the times that the moderators used the rectangle tool to censor content. For example, you might want to make a NSFW compilation of the last moments of each artwork right before it gets censored.
#
# We can do this by loading the original gzipped CSV file, filtering out only the rows with four coordinates, and storing them in a dataframe.

# %%
import pandas as pd

csv_iterator = pd.read_csv(
    "../../data/2022_place_canvas_history.csv.gzip",
    chunksize=100_000,
    compression="gzip",
)

df = pd.DataFrame(columns=["timestamp", "user_id", "pixel_color", "coordinate"])

for chunk in csv_iterator:
    for row in chunk.itertuples():
        if len(row[4].split(",")) == 4:
            df.loc[len(df)] = row[1:]

df = df.sort_values(by=["timestamp"], ignore_index=True)
df
# Out:
#                       timestamp  \
# 0   2022-04-01 14:44:08.158 UTC
# 1   2022-04-01 14:46:23.652 UTC
# 2   2022-04-01 14:46:39.702 UTC
# 3    2022-04-03 23:03:29.93 UTC
# 4   2022-04-03 23:05:04.703 UTC
# 5   2022-04-03 23:08:50.038 UTC
# 6   2022-04-03 23:10:36.803 UTC
# 7   2022-04-03 23:12:51.382 UTC
# 8   2022-04-03 23:29:52.139 UTC
# 9   2022-04-04 01:22:50.891 UTC
# 10  2022-04-04 04:12:20.372 UTC
# 11  2022-04-04 04:16:10.416 UTC
# 12  2022-04-04 04:29:41.896 UTC
# 13  2022-04-04 15:58:33.239 UTC
# 14  2022-04-04 15:59:10.926 UTC
# 15    2022-04-04 19:29:49.2 UTC
# 16  2022-04-04 19:29:49.559 UTC
# 17    2022-04-04 19:29:49.9 UTC
# 18  2022-04-04 19:29:50.051 UTC
#
#                                               user_id pixel_color  \
# 0   UY7pWDspuiKPKlsEMYNjkKYnoLkwPW0/ezIl++dHkTpFQ5...     #898D90
# 1   yVC1UzwQLjSlhK6lV9kzwwlj0nzEfZ31d1EnR4enIpDpRO...     #898D90
# 2   2ES5f0pi/aKJosil5Q8+t4zrjOhkOgZKcvIOCVLW6djCrc...     #898D90
# 3   q/Dk6lmcXm8bcDbNIhDglz7kFuCmX6zkca9UPivDix5WWi...     #FFB470
# 4   m8NEcPbf5XRV5ppeuZ3KLIYAG8GuHkNIxOEsCD06Ey8I1E...     #FFB470
# 5   LKS2u3QL2N3Olv7rnUCWry4KJ5K4Ea+/9qKyadTNl01apE...     #FFB470
# 6   HkR0yRQUJ1wsjh4Zo4VdKE43IctIGMFS9VuVm9IyCFcPOA...     #FFF8B8
# 7   7JiQyrONpFJphvBEPVUGyxjBsdvU8fuiSVzpMuTkxFDjqt...     #FFF8B8
# 8   gS0DWvPgaiQkHvG4NsHveLvpn8uf50t+sOY3nIykDvkyEd...     #FFB470
# 9   q+XjkQ6WRx0aBLtb2xRGWBrsHALXejJxEE2hs6sDJHfN2L...     #000000
# 10  gXOuxCyb/dslyRb5GQW+JbG9NRxMHxGGV3V5018ha4bVrU...     #000000
# 11  oPv1iZrj4UMjfhzOTVNZKwNe6u/bNG2Tabw8H7UOABps62...     #000000
# 12  Tqn87vyPxAHtPMu4xuAqTHkBvUhFi/BKLnQ0XyEraQ3ut9...     #000000
# 13  vnCNr84RaVDsTzLffAYaiEcF/4WIDDBEk/hKsFX7HO9hVO...     #94B3FF
# 14  8dCm+y4XG/R21ijH9er0xcYdMU3lFaCgIyUYHhdk5nR5uc...     #94B3FF
# 15  Ps64FZelo7/8upEdCIU3ZZV5Xho2lfCF8ybTQBM7isSkTU...     #2450A4
# 16  FJD0LHykwotIeUCO9fNUIhWOOmO1Us12tQCCBad2k4bhHs...     #898D90
# 17  wpjJ1TbSwZtj96n9Zj5XxUbr5Z0Ed11Ef0szGgm+XRRV9v...     #00CC78
# 18  2U70JUfTVJoWF40aa3CVRKR1R7XcehHNbgA6BTOIPTjeZQ...     #B44AC0
#
#              coordinate
# 0       862,540,868,544
# 1       862,540,873,545
# 2       871,546,878,550
# 3     298,1770,334,1803
# 4     298,1805,329,1839
# 5     257,1736,296,1780
# 6     251,1805,296,1812
# 7     271,1835,296,1859
# 8     297,1750,364,1813
# 9   1349,1718,1424,1752
# 10     23,1523,172,1792
# 11     44,1652,165,1899
# 12     51,1691,154,1807
# 13    551,1311,562,1342
# 14    547,1330,550,1342
# 15  1373,1400,1419,1436
# 16  1371,1438,1418,1472
# 17  1372,1472,1406,1497
# 18  1375,1355,1424,1399

# %% [markdown]
# It might be more useful to have the timestamp in milliseconds, like in the Parquet dataset we used to create the color and age maps.

# %%
from datetime import datetime

# The length of time in milliseconds after 1970-01-01T00:00:00.000 UTC that
# the first pixel was placed in r/Place 2022.
START_TIME = 1648806250315


def parse_timestamp(timestamp):
    """Convert a YYYY-MM-DD HH:MM:SS.SSS timestamp to milliseconds after the start of r/Place 2022."""
    date_format = "%Y-%m-%d %H:%M:%S.%f"
    try:
        # Remove the UTC timezone from the timestamp and convert it to a POSIX timestamp.
        timestamp = datetime.strptime(timestamp[:-4], date_format).timestamp()
    except ValueError:
        # The timestamp is exactly on the second, so there is no decimal (%f).
        # This happens 1/1000 of the time.
        timestamp = datetime.strptime(timestamp[:-4], date_format[:-3]).timestamp()

    # Convert from a float in seconds to an int in milliseconds
    timestamp *= 1000.0
    timestamp = int(timestamp)

    # The earliest timestamp is 1648806250315, so subtract that from each timestamp
    # to get the time in milliseconds since the beginning of the experiment.
    timestamp -= START_TIME

    return timestamp


df = df.assign(timestamp=df.timestamp.apply(parse_timestamp))
df
# Out:
#     timestamp                                            user_id pixel_color  \
# 0     7197843  UY7pWDspuiKPKlsEMYNjkKYnoLkwPW0/ezIl++dHkTpFQ5...     #898D90
# 1     7333337  yVC1UzwQLjSlhK6lV9kzwwlj0nzEfZ31d1EnR4enIpDpRO...     #898D90
# 2     7349387  2ES5f0pi/aKJosil5Q8+t4zrjOhkOgZKcvIOCVLW6djCrc...     #898D90
# 3   209959615  q/Dk6lmcXm8bcDbNIhDglz7kFuCmX6zkca9UPivDix5WWi...     #FFB470
# 4   210054388  m8NEcPbf5XRV5ppeuZ3KLIYAG8GuHkNIxOEsCD06Ey8I1E...     #FFB470
# 5   210279723  LKS2u3QL2N3Olv7rnUCWry4KJ5K4Ea+/9qKyadTNl01apE...     #FFB470
# 6   210386488  HkR0yRQUJ1wsjh4Zo4VdKE43IctIGMFS9VuVm9IyCFcPOA...     #FFF8B8
# 7   210521067  7JiQyrONpFJphvBEPVUGyxjBsdvU8fuiSVzpMuTkxFDjqt...     #FFF8B8
# 8   211541824  gS0DWvPgaiQkHvG4NsHveLvpn8uf50t+sOY3nIykDvkyEd...     #FFB470
# 9   218320576  q+XjkQ6WRx0aBLtb2xRGWBrsHALXejJxEE2hs6sDJHfN2L...     #000000
# 10  228490057  gXOuxCyb/dslyRb5GQW+JbG9NRxMHxGGV3V5018ha4bVrU...     #000000
# 11  228720101  oPv1iZrj4UMjfhzOTVNZKwNe6u/bNG2Tabw8H7UOABps62...     #000000
# 12  229531581  Tqn87vyPxAHtPMu4xuAqTHkBvUhFi/BKLnQ0XyEraQ3ut9...     #000000
# 13  270862924  vnCNr84RaVDsTzLffAYaiEcF/4WIDDBEk/hKsFX7HO9hVO...     #94B3FF
# 14  270900611  8dCm+y4XG/R21ijH9er0xcYdMU3lFaCgIyUYHhdk5nR5uc...     #94B3FF
# 15  283538885  Ps64FZelo7/8upEdCIU3ZZV5Xho2lfCF8ybTQBM7isSkTU...     #2450A4
# 16  283539244  FJD0LHykwotIeUCO9fNUIhWOOmO1Us12tQCCBad2k4bhHs...     #898D90
# 17  283539585  wpjJ1TbSwZtj96n9Zj5XxUbr5Z0Ed11Ef0szGgm+XRRV9v...     #00CC78
# 18  283539736  2U70JUfTVJoWF40aa3CVRKR1R7XcehHNbgA6BTOIPTjeZQ...     #B44AC0
#
#              coordinate
# 0       862,540,868,544
# 1       862,540,873,545
# 2       871,546,878,550
# 3     298,1770,334,1803
# 4     298,1805,329,1839
# 5     257,1736,296,1780
# 6     251,1805,296,1812
# 7     271,1835,296,1859
# 8     297,1750,364,1813
# 9   1349,1718,1424,1752
# 10     23,1523,172,1792
# 11     44,1652,165,1899
# 12     51,1691,154,1807
# 13    551,1311,562,1342
# 14    547,1330,550,1342
# 15  1373,1400,1419,1436
# 16  1371,1438,1418,1472
# 17  1372,1472,1406,1497
# 18  1375,1355,1424,1399
